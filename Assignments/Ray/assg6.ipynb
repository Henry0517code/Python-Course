# %% [markdown]
# ## 🎨 1. Magic Painting Contest: Advanced Round
#
# ### Description
#
# You are building an **Magic Painting Contest** system. Each contestant paints with a set of **colors** and optionally applies **special effects**. The more **vibrant** the colors and the more **creative** the effects, the higher the painting score.
#
# Your goal is to write a function `create_painting(name, *colors, **effects)` that:
#
# 1. Prints the artist's name.
# 2. Validates and reports how many **valid colors** are used.
# 3. Prints and scores each **special effect** based on custom rules.
# 4. Outputs a **total creativity score** for the painting.
#
# ### Custom Rules
#
# * **Color Rules**:
#
#   * Only count the following as valid colors: `"red"`, `"blue"`, `"green"`, `"yellow"`, `"purple"`, `"orange"`, `"black"`, `"white"`.
#   * Ignore invalid or unknown colors.
#   * Each valid color contributes **5 points** to the score.
#
# * **Effect Scoring (examples)**:
#
#   | Effect   | Score                                 |
#   | -------- | ------------------------------------- |
#   | sparkles | 10 if True                            |
#   | glow     | "low" → 5, "medium" → 10, "high" → 15 |
#   | shadow   | 7 if True                             |
#   | glitter  | 5 if True                             |
#
#   * Any unknown effect contributes **0 points**.
#
# ### Requirements
#
# 1. Use `*args` for colors, `**kwargs` for effects.
# 2. Use **loops** and **conditionals** to validate and score entries.
# 3. Use `.get()` for effect scoring (with default score of 0).
# 4. At the end, **print the final creativity score**.
#
# ### Sample Function Call
#
# ```python
# create_painting(
#     "Luna",
#     "red", "silver", "blue", "sparkly green", "black",
#     sparkles=True,
#     glow="medium",
#     shadow=True,
#     glitter=False
# )
# ```
#
# ### Sample Output
#
# ```ascii
# 🎨 Luna is painting a masterpiece!
# Valid colors used: red, blue, black
# Colors score: 15
#
# Special effects applied:
# - sparkles: +10
# - glow (medium): +10
# - shadow: +7
# - glitter: +0
#
# 🎉 Final Creativity Score: 42
# ```

# %%
# Answer Here!

# %% [markdown]
# ## 🧩 2. Expanding the Combat Game
#
# ### 🗡️ Context
#
# You’ve built a modular turn-based combat system in Python that supports attacking, healing, and status effects like stun. Now it’s time to **level up** the design by adding **three new features**, while maintaining a modular structure (one feature per module).
#
# ### 🧪 Task: Implement These 2 New Features
#
# #### 1. **Let the Player Decide**
#
# Modify the existing logic so that instead of two computer-controlled entities fighting, **you (the user)** play as one of the characters.
#
# * One player is **you** (the human), the other is the **computer** (random choices).
# * In each of your turns:
#
#   * The game displays the current HP and status of both players.
#   * You are given a list of choices:
#
#     ```
#     What would you like to do?
#     1. Attack
#     2. Heal
#     3. Shield
#     ```
#   * Based on your input (e.g. `1`, `2`, etc.), the appropriate action is executed.
# * For the **computer**, use `random.choice()` to choose among available actions.
#
# #### 2. **Shield Mechanic**
#
# * Create a new module called `shield.py`.
# * Add a function:
#
#   ```python
#   def cast_shield(caster):
#       ...
#   ```
# * When used:
#
#   * Set `caster["shield"] = True` (active for one turn).
# * Update `attack.py` so that:
#
#   * If the target has `"shield" == True`, the incoming damage is halved (rounded down).
#   * After the shield absorbs a hit, it is removed (`target["shield"] = False`).
#
# ### 📌 Reminder: Keep It Modular
#
# * Add new modules for each feature.
# * Only call logic from `main.py`, do not mix implementation into `main.py`.
#
# Let me know if you'd like a starter template for the player input loop or computer AI turn!
