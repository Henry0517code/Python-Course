# %% [markdown]
# ## 1. Officer Meow: Cat Patrol 2
#
# ### Description
#
# Officer Meow is back on patrol! This time, the task is to manage a list of cats by identifying and removing bad cats within a specified range. You will start with an empty list, add a series of new cats, and then identify which cats are "bad" based on user-specified start and end positions in the list. Finally, you will remove these bad cats from the list.
#
# Your task is to write a Python program that performs these operations using slicing to identify the bad cats and a loop to remove them.
#
# ### Requirements:
#
# 1. Start with an empty list of cats.
# 2. Append a given list of new cats to the `cats` list.
# 3. Ask the user to enter the start and end positions of the bad cats range.
# 4. Use the slice operator to identify the bad cats within this range and remove them from the `cats` list.
# 5. Print the updated list of cats after removing the bad cats.
#
# ### Sample Input
#
# ```python
# # Start with an empty list of cats
# cats = []
#
# # List of new cats to be added
# new_cats = ['cat #10', 'cat #3', 'cat #12', 'cat #8', 'cat #15', 'cat #5', 'cat #1']
# ```
#
# ```ascii
# Where's the start of the bad cats?
# 2
# Where's the end of the bad cats?
# 6
# ```
#
# ### Sample Output
#
# ```ascii
# After appending new cats: ['cat #10', 'cat #3', 'cat #12', 'cat #8', 'cat #15', 'cat #5', 'cat #1']
# Identified bad cats in the range: ['cat #12', 'cat #8', 'cat #15', 'cat #5']
# After removing bad cats: ['cat #10', 'cat #3', 'cat #1']
# ```
#
# ### Hints:
#
# - Use `list[start: end]` to slice the list and identify the bad cats. Remember that `end` is exclusive in Python slicing.

# %%
# Start with an empty list of cats
cats = []

# List of new cats to be added
new_cats = ['cat #10', 'cat #3', 'cat #12', 'cat #8', 'cat #15', 'cat #5', 'cat #1']

# Answer Here!

# %% [markdown]
# ## 2. Doctor Meow Meow: The Feline Health Inspector
#
# ### Description
#
# Doctor Meow Meow, the famed feline health inspector, is on a mission to check the health of 30 townsfolk by calculating their Body Mass Index (BMI). Each townsperson's BMI needs to be calculated and assessed to identify who might need a bit more exercise... or maybe just a nice nap.
#
# Your task is to help Doctor Meow Meow analyze the data. Given a list of names, heights, and weights, calculate the BMI for each person, print it out, and finally, reveal who has the smallest and largest BMI in town.
#
# BMI is calculated using the following formula:
#
# $
# \text{BMI} = \frac{\text{weight (kg)}}{\left(\text{height (m)}\right)^2}
# $
#
# ### Requirements:
#
# 1. Use a `for` loop with `range` to iterate over each person’s information and calculate their BMI.
#
# 2. Identify and print the names of the person with the smallest and largest BMI.
#
# ### Sample Input
#
# Data are structured as follows:
#
# ```python
# # List of names
# names = [
#     "Alice", "Bob", "Charlie", "David", "Ella", "Frank", "Grace", "Hank", "Ivy", "Jack",
#     "Karen", "Leo", "Mia", "Nina", "Oscar", "Paula", "Quinn", "Rick", "Sophie", "Tom",
#     "Uma", "Vera", "Will", "Xena", "Yara", "Zane", "Amy", "Ben", "Cleo", "Dan"
# ]
#
# # List of heights in cm
# heights = [
#     165, 175, 180, 160, 155, 170, 168, 182, 158, 176,
#     167, 174, 159, 162, 178, 164, 169, 181, 160, 172,
#     157, 166, 179, 163, 161, 177, 156, 183, 171, 175
# ]
#
# # List of weights in kg
# weights = [
#     68, 70, 75, 60, 55, 72, 65, 80, 54, 77,
#     66, 68, 58, 62, 82, 64, 70, 79, 59, 75,
#     57, 66, 85, 63, 61, 74, 56, 78, 67, 73
# ]
# ```
#
# ### Sample Output
#
# ```ascii
# Alice's BMI: 24.98
# Bob's BMI: 22.86
# Charlie’s BMI: 23.15
# David’s BMI: 23.44
# Ella’s BMI: 22.88
# ...
# Person with the smallest BMI: Ivy (21.64)
# Person with the largest BMI: Will (26.56)
# ```
#
# ### Hints
#
# - You may use `list.index()` to retrieve the name associated with the min/max BMI.
# - Example: `[22.5, 24.3, 19.8].index(19.8)` will return `2`, which you can use to access the correct name from the `names` list.

# %%
names = [
    "Alice", "Bob", "Charlie", "David", "Ella", "Frank", "Grace", "Hank", "Ivy", "Jack",
    "Karen", "Leo", "Mia", "Nina", "Oscar", "Paula", "Quinn", "Rick", "Sophie", "Tom",
    "Uma", "Vera", "Will", "Xena", "Yara", "Zane", "Amy", "Ben", "Cleo", "Dan"
]

# List of heights in cm
heights = [
    165, 175, 180, 160, 155, 170, 168, 182, 158, 176,
    167, 174, 159, 162, 178, 164, 169, 181, 160, 172,
    157, 166, 179, 163, 161, 177, 156, 183, 171, 175
]

# List of weights in kg
weights = [
    68, 70, 75, 60, 55, 72, 65, 80, 54, 77,
    66, 68, 58, 62, 82, 64, 70, 79, 59, 75,
    57, 66, 85, 63, 61, 74, 56, 78, 67, 73
]

# Answer Here!

# %% [markdown]
# ## Submission
#
# Remember to submit your assignment at [**Google Drive**](https://drive.google.com/drive/folders/1r-KcMK5K-gwQklVu7e33sAiFOadtNBLD?usp=sharing).
#
# Only the `.ipynb` file should be submitted, and make sure to name your file in the following format:
# - For **Assignment 1**, use `name_assg1.ipynb`, e.g. `henry_assg1.ipynb`
# - For **Assignment 2**, use `name_assg2.ipynb`
#
# #### Note: Make sure you collect discriptions and answers of all problems into a single .ipynb file.
