# %% [markdown]
# ## 1. Library Book Lookup
#
# ### Description
#
# You are tasked with designing a simple **Library Book Lookup** system. The library keeps track of its books using a dictionary, where the book title is the key, and the value is the book's availability status (`"Available"` or `"Checked Out"`).
#
# The program should:
# 1. Allow the user to input a book title they want to look up.
# 2. Use the `.get()` method to check if the book exists in the library.
# 3. If the book exists, display its availability status.
# 4. If the book doesn’t exist, inform the user that the book is not in the library.
#
# ### Library Data
#
# ```python
# library = {
#     "The Great Gatsby": "Available",
#     "To Kill a Mockingbird": "Checked Out",
#     "1984": "Available",
#     "Moby Dick": "Checked Out",
#     "Pride and Prejudice": "Available"
# }
# ```
#
# ### Requirements
#
# 1. If the book exists, print its availability status.
# 2. If the book doesn’t exist, return a default message like `"Sorry, this book is not in our library."`.
#
# ### Sample Interaction
#
# ```ascii
# Which book are you looking for? 1984
# 1984 is Available.
# ```
#
# ```ascii
# Which book are you looking for? Harry Potter
# Sorry, this book is not in our library.
# ```
#
# ### Hints
#
# 1. **Use `.get(key, default)`**:

# %%
# Answer Here!
library = {
    "The Great Gatsby": "Available",
    "To Kill a Mockingbird": "Checked Out",
    "1984": "Available",
    "Moby Dick": "Checked Out",
    "Pride and Prejudice": "Available"
}

# %% [markdown]
# ## 2. Space Exploration Success Tracker
#
# ### Description
#
# You are tasked with designing a program to manage data about a **space exploration project**. The program tracks multiple planets, each with several missions. Each mission has specific details such as the year it started, the spacecraft used, and its success status.
#
# The data is stored in a **nested dictionary**, structured as:
# - **Planet name** → **Mission name** → **Mission details (year, spacecraft, success)**
#
# Your program will allow users to:
# 1. View all **successful missions** for a specific planet.
#
# ### Data
#
# ```python
# space_data = {
#     "Mars": {
#         "Curiosity": {"year": 2012, "spacecraft": "MSL", "success": True},
#         "Viking 1": {"year": 1976, "spacecraft": "Viking", "success": True},
#         "Schiaparelli": {"year": 2016, "spacecraft": "ExoMars", "success": False}
#     },
#     "Jupiter": {
#         "Juno": {"year": 2011, "spacecraft": "Atlas V", "success": True},
#         "Galileo": {"year": 1989, "spacecraft": "Space Shuttle Atlantis", "success": True}
#     },
#     "Venus": {
#         "Venera 7": {"year": 1970, "spacecraft": "Molniya", "success": True},
#         "Magellan": {"year": 1989, "spacecraft": "STS-30", "success": True}
#     }
# }
# ```
#
# ### Requirements
#
# 1. **View Successful Missions**:
#    - Display all missions where the `success` field is `True`, along with their details (year and spacecraft).
# 2. **Use For Loop**:
#    - Use for loops to iterate over the data.
#
# ### Sample Output
#
# ```ascii
# Curiosity on Mars was a success in 2012 with a MSL.
# Viking 1 on Mars was a success in 1976 with a Viking.
# Juno on Jupiter was a success in 2011 with a Atlas V.
# Galileo on Jupiter was a success in 1989 with a Space Shuttle Atlantis.
# Venera 7 on Venus was a success in 1970 with a Molniya.
# Magellan on Venus was a success in 1989 with a STS-30.
# ```
#
# ### Hints
#
# You can see the nested dictionary as:
# 1. Data: PlanetName -> Missions
# 2. Misssion: MissionName -> Details
# 3. Detail: InfoName -> Value
#
# Thus, in order to loop over the data, you can use:
#
# ```python
# for planet_name, missions in space_data.items():
#     ...
# ```

# %%
# Answer Here!
space_data = {
    "Mars": {
        "Curiosity": {"year": 2012, "spacecraft": "MSL", "success": True},
        "Viking 1": {"year": 1976, "spacecraft": "Viking", "success": True},
        "Schiaparelli": {"year": 2016, "spacecraft": "ExoMars", "success": False}
    },
    "Jupiter": {
        "Juno": {"year": 2011, "spacecraft": "Atlas V", "success": True},
        "Galileo": {"year": 1989, "spacecraft": "Space Shuttle Atlantis", "success": True}
    },
    "Venus": {
        "Venera 7": {"year": 1970, "spacecraft": "Molniya", "success": True},
        "Magellan": {"year": 1989, "spacecraft": "STS-30", "success": True}
    }
}

# %% [markdown]
# ## 3. Movie Night Organizer
#
# ### Description
#
# You are tasked with organizing a **Movie Night** for a group of friends. Each friend has their own list of favorite movies, and their preferences are stored in a dictionary. Your program will help recommend the **most liked movie** for the group.
#
# | Friend   | Favorite Movies                      |
# |----------|--------------------------------------|
# | Alice    | Inception, Titanic, Avatar           |
# | Bob      | Avatar, The Matrix, Titanic          |
# | Charlie  | Inception, Avatar, The Lion King     |
#
# Your job is to identify the **most liked movie** (the movie mentioned the most across all friends).
#
# ### Requirements:
#
# 1. Use a **dictionary of lists** where the keys are friends' names and the values are their favorite movies.
# 2. Use a **for loop** to count how many times each movie is mentioned.
# 3. Display the most liked movie based on the counts.
#
# ### Sample Output
#
# ```ascii
# Most liked movie: Avatar
# ```
#
# ### Hints:
#
# 1. **Count Movie Mentions**:
#    Use a dictionary to track how many times each movie is mentioned. Example:
#    ```python
#    counts['Avatar'] = counts.get('Avatar', 0) + 1
#    ```
#
# 2. **Find the Most Liked Movie**:
#    Keep track of the most liked movie and its count. Update if necessary. Example:
#    ```python
#    most_liked = ""
#    max_count = 0
#    for movie, count in friends_movies.values():
#       if ...
#    ```

# %%
# Answer Here!
